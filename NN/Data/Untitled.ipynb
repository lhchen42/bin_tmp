# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data_ex_labeled.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  filename_A  store_A  put_A  \
# 0           0             0  gcc_coreutils8.31_O2_chown     2819  18959
# 1           1             1  gcc_coreutils8.31_O2_chown     2819  18959
# 2           2             2  gcc_coreutils8.31_O2_chown     2819  18959
# 3           3             3  gcc_coreutils8.31_O2_chown     2819  18959
# 4           4             4  gcc_coreutils8.31_O2_chown     2819  18959
#
#    wrtmp_A  loadg_A  storeg_A  cas_A  sucessors_A  ...  \
# 0    30284        0         0      0         4757  ...
# 1    30284        0         0      0         4757  ...
# 2    30284        0         0      0         4757  ...
# 3    30284        0         0      0         4757  ...
# 4    30284        0         0      0         4757  ...
#
#                      filename_B store_B  put_B  wrtmp_B  loadg_B  storeg_B  \
# 0    gcc_coreutils8.31_O3_users    2874  15613    20126        0         0
# ...

# %%
#df.drop(['Unnamed:0', 'Unnamed:0.1'], axis=1)
df.columns[0:2]
new_df = df.drop(df.columns[0:2], axis=1)

# %%
new_df.head()
# Out:
#                    filename_A  store_A  put_A  wrtmp_A  loadg_A  storeg_A  \
# 0  gcc_coreutils8.31_O2_chown     2819  18959    30284        0         0
# 1  gcc_coreutils8.31_O2_chown     2819  18959    30284        0         0
# 2  gcc_coreutils8.31_O2_chown     2819  18959    30284        0         0
# 3  gcc_coreutils8.31_O2_chown     2819  18959    30284        0         0
# 4  gcc_coreutils8.31_O2_chown     2819  18959    30284        0         0
#
#    cas_A  sucessors_A  predecessors_A                    filename_B  store_B  \
# 0      0         4757            4757    gcc_coreutils8.31_O3_users     2874
# 1      0         4757            4757    gcc_coreutils8.31_O1_tsort     1365
# 2      0         4757            4757     gcc_coreutils8.31_O1_nice     1116
# 3      0         4757            4757     gcc_coreutils8.31_O1_true      997
# 4      0         4757            4757  gcc_coreutils8.31_O0_sha1sum     2299
#
# ...
