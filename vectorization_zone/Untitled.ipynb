# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data.csv", dtype=str)
new_df = pd.DataFrame(columns=['filename_A', "store_A","put_A","wrtmp_A","loadg_A","storeg_A","cas_A","sucessors_A","predecessors_A",'filename_B', "store_B","put_B","wrtmp_B","loadg_B","storeg_B","cas_B","sucessors_B","predecessors_B"])
df_tmp = df.copy()

# %%
counter = 0

# %%
for index, row in df.iterrows():
    df_tmp = df_tmp.drop(index)
    for an_index, an_row in df_tmp.iterrows():
        new_df = new_df.append({'filename_A':row['filename'],
                       "store_A":row['store'],
                       "put_A":row['put'],
                       "wrtmp_A":row['wrtmp'],
                       "loadg_A":row['loadg'],
                       "storeg_A":row['storeg'],
                       "cas_A":row['cas'],
                       "sucessors_A":row['sucessors'],
                       "predecessors_A":row['predecessors'],
                       'filename_B':an_row['filename'],
                       "store_B":an_row['store'],
                       "put_B":an_row['put'],
                       "wrtmp_B":an_row['wrtmp'],
                       "loadg_B":an_row['loadg'],
                       "storeg_B":an_row['storeg'],
                       "cas_B":an_row['cas'],
                       "sucessors_B":an_row['sucessors'],
                       "predecessors_B":an_row['predecessors']
        }, ignore_index=True)
        counter+=1

# %%
new_df.head(n=30)
# Out:
#                     filename_A store_A  put_A wrtmp_A loadg_A storeg_A cas_A  \
# 0   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 1   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 2   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 3   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 4   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 5   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 6   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 7   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 8   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 9   gcc_coreutils8.31_O2_chown    2819  18959   30284       0        0     0
# 10  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 11  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 12  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 13  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 14  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 15  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 16  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 17  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 18  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 19  gcc_coreutils8.31_O3_users    2874  15613   20126       0        0     0
# 20  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 21  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 22  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 23  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 24  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 25  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 26  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 27  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 28  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
# 29  gcc_coreutils8.31_O1_tsort    1365   7281   12269       0        0     0
#
#    sucessors_A predecessors_A                    filename_B store_B  put_B  \
# 0         4757           4757    gcc_coreutils8.31_O3_users    2874  15613
# 1         4757           4757    gcc_coreutils8.31_O1_tsort    1365   7281
# 2         4757           4757     gcc_coreutils8.31_O1_nice    1116   6156
# 3         4757           4757     gcc_coreutils8.31_O1_true     997   5372
# 4         4757           4757  gcc_coreutils8.31_O0_sha1sum    2299  11549
# 5         4757           4757     gcc_coreutils8.31_O0_sort    6368  35389
# 6         4757           4757       gcc_coreutils8.31_O2_tr    1733  11413
# 7         4757           4757    gcc_coreutils8.31_O0_pinky    1812   8693
# 8         4757           4757    gcc_coreutils8.31_O2_chmod    2532  17298
# 9         4757           4757      gcc_coreutils8.31_O0_cat    1770   8535
# 10        2682           2682    gcc_coreutils8.31_O1_tsort    1365   7281
# 11        2682           2682     gcc_coreutils8.31_O1_nice    1116   6156
# 12        2682           2682     gcc_coreutils8.31_O1_true     997   5372
# 13        2682           2682  gcc_coreutils8.31_O0_sha1sum    2299  11549
# 14        2682           2682     gcc_coreutils8.31_O0_sort    6368  35389
# 15        2682           2682       gcc_coreutils8.31_O2_tr    1733  11413
# 16        2682           2682    gcc_coreutils8.31_O0_pinky    1812   8693
# 17        2682           2682    gcc_coreutils8.31_O2_chmod    2532  17298
# 18        2682           2682      gcc_coreutils8.31_O0_cat    1770   8535
# 19        2682           2682   gcc_coreutils8.31_O2_base64    1460   9363
# 20        1879           1879     gcc_coreutils8.31_O1_nice    1116   6156
# 21        1879           1879     gcc_coreutils8.31_O1_true     997   5372
# 22        1879           1879  gcc_coreutils8.31_O0_sha1sum    2299  11549
# 23        1879           1879     gcc_coreutils8.31_O0_sort    6368  35389
# 24        1879           1879       gcc_coreutils8.31_O2_tr    1733  11413
# 25        1879           1879    gcc_coreutils8.31_O0_pinky    1812   8693
# 26        1879           1879    gcc_coreutils8.31_O2_chmod    2532  17298
# 27        1879           1879      gcc_coreutils8.31_O0_cat    1770   8535
# 28        1879           1879   gcc_coreutils8.31_O2_base64    1460   9363
# 29        1879           1879   gcc_coreutils8.31_O2_stdbuf    1871  12579
#
#    wrtmp_B loadg_B storeg_B cas_B sucessors_B predecessors_B
# 0    20126       0        0     0        2682           2682
# 1    12269       0        0     0        1879           1879
# 2    10512       0        0     0        1588           1588
# 3     9066       0        0     0        1332           1332
# 4    25496       0        0     0        2561           2561
# 5    66281       0        0     0        8009           8009
# 6    17786       0        0     0        2714           2714
# 7    14775       0        0     0        2092           2092
# 8    28701       0        0     0        4302           4302
# 9    14601       0        0     0        2003           2003
# 10   12269       0        0     0        1879           1879
# 11   10512       0        0     0        1588           1588
# 12    9066       0        0     0        1332           1332
# 13   25496       0        0     0        2561           2561
# 14   66281       0        0     0        8009           8009
# 15   17786       0        0     0        2714           2714
# 16   14775       0        0     0        2092           2092
# 17   28701       0        0     0        4302           4302
# 18   14601       0        0     0        2003           2003
# 19   14707       0        0     0        2083           2083
# 20   10512       0        0     0        1588           1588
# 21    9066       0        0     0        1332           1332
# 22   25496       0        0     0        2561           2561
# 23   66281       0        0     0        8009           8009
# 24   17786       0        0     0        2714           2714
# 25   14775       0        0     0        2092           2092
# 26   28701       0        0     0        4302           4302
# 27   14601       0        0     0        2003           2003
# 28   14707       0        0     0        2083           2083
# 29   20500       0        0     0        3046           3046
